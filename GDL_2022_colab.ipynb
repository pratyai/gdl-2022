# %%
# !pip install torch===1.10.1 torchvision===0.11.2 torchaudio===0.10.1 pytorch-lightning -f https://download.pytorch.org/whl/torch_stable.html
# !pip install torch-sparse torch-scatter -f https://data.pyg.org/whl/torch-1.10.1+cpu.html
# !pip install torch-geometric -f https://data.pyg.org/whl/torch-1.10.1+cpu.html
# !git clone https://github.com/TorchSpatiotemporal/tsl.git
# !pip install ./tsl

# %%
# %cd "/content/drive/MyDrive/gdl 2022"
# !git clone https://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@github.com/pratyai/gdl-2022.git
# %cd "/content/drive/MyDrive/gdl 2022/gdl-2022/"
# %ls
# Out:
# /content/drive/MyDrive/gdl 2022
# fatal: destination path 'gdl-2022' already exists and is not an empty directory.
# /content/drive/MyDrive/gdl 2022/gdl-2022
# imputation/  log/  README.md  run_imputation.ipynb  saved_model/

# %%
# !python3 "imputation/run_imputation.py" --quantile=0.025
# Out:
# Global seed set to 561057674
# 2022-05-08 21:14:17,356 [INFO]: SEED: 561057674
# 2022-05-08 21:14:19,154 [INFO]: Generating mask with base p=0.0
# 2022-05-08 21:14:19,256 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.025
# seed                : 561057674
# precision           : 32
# model_name          : grin
# dataset_name        : la_point
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# l2_reg              : 0.0
# epochs              : 300
# batches_per_epoch   : 160
# patience            : 50
# grad_clip_val       : 5.0
# use_lr_schedule     : True
# save_preds          : False
# neptune_logger      : False
# project_name        : sandbox
# tags                : ()
# hidden_size         : 64
# ...

# %%
# !python3 "imputation/run_imputation.py" --quantile=0.975
# Out:
# Global seed set to 518665962
# 2022-05-09 08:15:07,106 [INFO]: SEED: 518665962
# 2022-05-09 08:15:08,740 [INFO]: Generating mask with base p=0.0
# 2022-05-09 08:15:08,844 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.975
# seed                : 518665962
# precision           : 32
# model_name          : grin
# dataset_name        : la_point
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# l2_reg              : 0.0
# epochs              : 300
# batches_per_epoch   : 160
# patience            : 50
# grad_clip_val       : 5.0
# use_lr_schedule     : True
# save_preds          : False
# neptune_logger      : False
# project_name        : sandbox
# tags                : ()
# hidden_size         : 64
# ...

# %%
# !python3 "imputation/run_imputation.py" --quantile=0.5
