# %%
# !pip install torch===1.10.1 torchvision===0.11.2 torchaudio===0.10.1 pytorch-lightning -f https://download.pytorch.org/whl/torch_stable.html
# !pip install torch-sparse torch-scatter -f https://data.pyg.org/whl/torch-1.10.1+cpu.html
# !pip install torch-geometric -f https://data.pyg.org/whl/torch-1.10.1+cpu.html
# !git clone https://github.com/TorchSpatiotemporal/tsl.git
# !pip install ./tsl
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |██████████████████████████████▎ | 834.1 MB 1.2 MB/s eta 0:00:39tcmalloc: large alloc 1147494400 bytes == 0x397b6000 @  0x7f4680ba9615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |████████████████████████████████| 881.9 MB 16 kB/s
# ...
#      |████████████████████████████████| 23.3 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 43.8 MB/s
# ...
#      |████████████████████████████████| 584 kB 62.0 MB/s
# ...
#      |████████████████████████████████| 136 kB 77.2 MB/s
# ...
#      |████████████████████████████████| 409 kB 62.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 65.8 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 58.7 MB/s
# ...

# %%
# %cd "/content/drive/MyDrive/gdl 2022"
# !git clone https://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@github.com/pratyai/gdl-2022.git
# %cd "/content/drive/MyDrive/gdl 2022/gdl-2022/"
# %ls
# Out:
# /content/drive/MyDrive/gdl 2022
# fatal: destination path 'gdl-2022' already exists and is not an empty directory.
# /content/drive/MyDrive/gdl 2022/gdl-2022
# GDL_2022_colab.ipynb  log/       run_imputation.ipynb
# imputation/           README.md  saved_model/

# %%
# !python3 "imputation/run_quantile_training.py" --quantile=0.025 --dataset-name=la_block
# Out:
# Global seed set to 463339520
# 2022-05-17 02:57:13,910 [INFO]: SEED: 463339520
# 2022-05-17 02:57:13,910 [INFO]: Downloading https://drive.switch.ch/index.php/s/Z8cKHAVyiDqkzaG/download
# download: 14.5MB [00:01, 7.30MB/s]
# 2022-05-17 02:57:15,891 [INFO]: Extracting /usr/local/lib/python3.7/dist-packages/tsl/.storage/MetrLA/download
# 2022-05-17 02:57:16,254 [INFO]: Building distance matrix...
# 2022-05-17 02:57:18,598 [INFO]: Generating mask with base p=0.0015
# 2022-05-17 02:57:18,777 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.025
# seed                : 463339520
# precision           : 32
# model_name          : grin
# dataset_name        : la_block
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# ...

# %%
# !python3 "imputation/run_quantile_training.py" --quantile=0.975 --dataset-name=la_block
# Out:
# Global seed set to 363870127
# 2022-05-17 09:29:53,658 [INFO]: SEED: 363870127
# 2022-05-17 09:29:55,355 [INFO]: Generating mask with base p=0.0015
# 2022-05-17 09:29:55,508 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.975
# seed                : 363870127
# precision           : 32
# model_name          : grin
# dataset_name        : la_block
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# l2_reg              : 0.0
# epochs              : 300
# batches_per_epoch   : 160
# patience            : 50
# grad_clip_val       : 5.0
# use_lr_schedule     : True
# save_preds          : False
# neptune_logger      : False
# project_name        : sandbox
# tags                : ()
# hidden_size         : 64
# ...

# %%
# !python3 "imputation/run_quantile_training.py" --quantile=0.0015 --dataset-name=la_block
# Out:
# Global seed set to 570130802
# 2022-05-17 17:09:28,346 [INFO]: SEED: 570130802
# 2022-05-17 17:09:29,968 [INFO]: Generating mask with base p=0.0015
# 2022-05-17 17:09:30,125 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.0015
# seed                : 570130802
# precision           : 32
# model_name          : grin
# dataset_name        : la_block
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# l2_reg              : 0.0
# epochs              : 300
# batches_per_epoch   : 160
# patience            : 50
# grad_clip_val       : 5.0
# use_lr_schedule     : True
# save_preds          : False
# neptune_logger      : False
# project_name        : sandbox
# tags                : ()
# hidden_size         : 64
# ...

# %%
# !python3 "imputation/run_quantile_training.py" --quantile=0.9985 --dataset-name=la_block
# Out:
# Global seed set to 143599611
# 2022-05-18 09:36:04,231 [INFO]: SEED: 143599611
# 2022-05-18 09:36:04,232 [INFO]: Downloading https://drive.switch.ch/index.php/s/Z8cKHAVyiDqkzaG/download
# download: 14.5MB [00:15, 936kB/s]
# 2022-05-18 09:36:19,663 [INFO]: Extracting /usr/local/lib/python3.7/dist-packages/tsl/.storage/MetrLA/download
# 2022-05-18 09:36:20,018 [INFO]: Building distance matrix...
# 2022-05-18 09:36:22,283 [INFO]: Generating mask with base p=0.0015
# 2022-05-18 09:36:22,429 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.9985
# seed                : 143599611
# precision           : 32
# model_name          : grin
# dataset_name        : la_block
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# ...

# %%
# !python3 "imputation/run_quantile_training.py" --quantile=0.16 --dataset-name=la_block
# Out:
# Global seed set to 102975960
# 2022-05-18 18:29:44,893 [INFO]: SEED: 102975960
# 2022-05-18 18:29:46,456 [INFO]: Generating mask with base p=0.0015
# 2022-05-18 18:29:46,606 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.16
# seed                : 102975960
# precision           : 32
# model_name          : grin
# dataset_name        : la_block
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# l2_reg              : 0.0
# epochs              : 300
# batches_per_epoch   : 160
# patience            : 50
# grad_clip_val       : 5.0
# use_lr_schedule     : True
# save_preds          : False
# neptune_logger      : False
# project_name        : sandbox
# tags                : ()
# hidden_size         : 64
# ...

# %%
# !python3 "imputation/run_quantile_training.py" --quantile=0.84 --dataset-name=la_block
# Out:
# Global seed set to 920931576
# 2022-05-19 00:45:02,156 [INFO]: SEED: 920931576
# 2022-05-19 00:45:03,795 [INFO]: Generating mask with base p=0.0015
# 2022-05-19 00:45:03,945 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.84
# seed                : 920931576
# precision           : 32
# model_name          : grin
# dataset_name        : la_block
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# l2_reg              : 0.0
# epochs              : 300
# batches_per_epoch   : 160
# patience            : 50
# grad_clip_val       : 5.0
# use_lr_schedule     : True
# save_preds          : False
# neptune_logger      : False
# project_name        : sandbox
# tags                : ()
# hidden_size         : 64
# ...
