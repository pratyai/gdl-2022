# %%
# !pip install setuptools===59.5.0
# !pip install torch===1.10.1 torchvision===0.11.2 torchaudio===0.10.1 pytorch-lightning -f https://download.pytorch.org/whl/torch_stable.html
# !pip install torch-sparse torch-scatter -f https://data.pyg.org/whl/torch-1.10.1+cpu.html
# !pip install torch-geometric -f https://data.pyg.org/whl/torch-1.10.1+cpu.html
# !git clone https://github.com/TorchSpatiotemporal/tsl.git
# !pip install ./tsl
# Out:
# Requirement already satisfied: setuptools===59.5.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (59.5.0)
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch===1.10.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (1.10.1)
# Requirement already satisfied: torchvision===0.11.2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: torchaudio===0.10.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (0.10.1)
# Requirement already satisfied: pytorch-lightning in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (1.6.2)
# Requirement already satisfied: typing-extensions in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch===1.10.1) (4.2.0)
# Requirement already satisfied: numpy in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torchvision===0.11.2) (1.22.3)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torchvision===0.11.2) (9.1.0)
# Requirement already satisfied: pyDeprecate<0.4.0,>=0.3.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch-lightning) (0.3.2)
# Requirement already satisfied: PyYAML>=5.4 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch-lightning) (0.8.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch-lightning) (2.9.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch-lightning) (2022.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch-lightning) (4.64.0)
# Requirement already satisfied: packaging>=17.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: aiohttp in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.8.1)
# Requirement already satisfied: requests in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from packaging>=17.0->pytorch-lightning) (3.0.8)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.44.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (3.20.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (59.5.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (3.3.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (2.1.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (2.6.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.37.1)
# Requirement already satisfied: six in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning) (4.11.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (6.0.2)
# Requirement already satisfied: zipp>=0.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning) (3.2.0)
# Looking in links: https://data.pyg.org/whl/torch-1.10.1+cpu.html
# Requirement already satisfied: torch-sparse in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (0.6.13)
# Requirement already satisfied: torch-scatter in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (2.0.9)
# Requirement already satisfied: scipy in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-sparse) (1.8.0)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from scipy->torch-sparse) (1.22.3)
# Looking in links: https://data.pyg.org/whl/torch-1.10.1+cpu.html
# Requirement already satisfied: torch-geometric in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (2.0.4)
# Requirement already satisfied: pandas in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-geometric) (1.4.2)
# Requirement already satisfied: tqdm in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-geometric) (4.64.0)
# Requirement already satisfied: pyparsing in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-geometric) (3.0.8)
# Requirement already satisfied: scikit-learn in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: requests in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-geometric) (2.27.1)
# Requirement already satisfied: jinja2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-geometric) (3.1.1)
# Requirement already satisfied: scipy in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-geometric) (1.8.0)
# Requirement already satisfied: numpy in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-geometric) (1.22.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from jinja2->torch-geometric) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pandas->torch-geometric) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pandas->torch-geometric) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->torch-geometric) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->torch-geometric) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->torch-geometric) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->torch-geometric) (2021.10.8)
# Requirement already satisfied: joblib>=0.11 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from scikit-learn->torch-geometric) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: six>=1.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->torch-geometric) (1.16.0)
# fatal: destination path 'tsl' already exists and is not an empty directory.
# Processing ./tsl
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: einops in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (0.4.1)
# Requirement already satisfied: numpy in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (1.22.3)
# Requirement already satisfied: pandas in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (1.4.2)
# Requirement already satisfied: pytorch_lightning>=1.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (1.6.2)
# Requirement already satisfied: PyYAML in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (6.0)
# Requirement already satisfied: scikit_learn in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (1.0.2)
# Requirement already satisfied: scipy in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (1.8.0)
# Requirement already satisfied: tables in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (3.7.0)
# Requirement already satisfied: test_tube in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (0.7.5)
# Requirement already satisfied: torch>=1.9 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (1.10.1)
# Requirement already satisfied: torch_geometric>=2.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (2.0.4)
# Requirement already satisfied: torchmetrics>=0.7 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (0.8.1)
# Requirement already satisfied: tqdm in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch-spatiotemporal==0.1.0) (4.64.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (2.9.0)
# Requirement already satisfied: packaging>=17.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (21.3)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (2022.3.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (4.2.0)
# Requirement already satisfied: pyDeprecate<0.4.0,>=0.3.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (0.3.2)
# Requirement already satisfied: jinja2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch_geometric>=2.0->torch-spatiotemporal==0.1.0) (3.1.1)
# Requirement already satisfied: pyparsing in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch_geometric>=2.0->torch-spatiotemporal==0.1.0) (3.0.8)
# Requirement already satisfied: requests in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from torch_geometric>=2.0->torch-spatiotemporal==0.1.0) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pandas->torch-spatiotemporal==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pandas->torch-spatiotemporal==0.1.0) (2022.1)
# Requirement already satisfied: joblib>=0.11 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from scikit_learn->torch-spatiotemporal==0.1.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from scikit_learn->torch-spatiotemporal==0.1.0) (3.1.0)
# Requirement already satisfied: numexpr>=2.6.2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tables->torch-spatiotemporal==0.1.0) (2.8.1)
# Requirement already satisfied: imageio>=2.3.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from test_tube->torch-spatiotemporal==0.1.0) (2.19.0)
# Requirement already satisfied: future in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from test_tube->torch-spatiotemporal==0.1.0) (0.18.2)
# Requirement already satisfied: aiohttp in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (3.8.1)
# Requirement already satisfied: pillow>=8.3.2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from imageio>=2.3.0->test_tube->torch-spatiotemporal==0.1.0) (9.1.0)
# Requirement already satisfied: six>=1.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->torch-spatiotemporal==0.1.0) (1.16.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (3.20.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (2.6.6)
# Requirement already satisfied: absl-py>=0.4 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (1.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (59.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (1.44.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->torch_geometric>=2.0->torch-spatiotemporal==0.1.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->torch_geometric>=2.0->torch-spatiotemporal==0.1.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->torch_geometric>=2.0->torch-spatiotemporal==0.1.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->torch_geometric>=2.0->torch-spatiotemporal==0.1.0) (1.26.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from jinja2->torch_geometric>=2.0->torch-spatiotemporal==0.1.0) (2.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (4.11.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (4.0.2)
# Requirement already satisfied: zipp>=0.5 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning>=1.5->torch-spatiotemporal==0.1.0) (3.2.0)
# Building wheels for collected packages: torch-spatiotemporal
#   Building wheel for torch-spatiotemporal (setup.py) ... done
#   Created wheel for torch-spatiotemporal: filename=torch_spatiotemporal-0.1.0-py3-none-any.whl size=157010 sha256=74d873ed98264b7613394d3955b3c455ee2ed623261eb66cd0f737b5959b5fbc
#   Stored in directory: /private/var/folders/3x/sjj1y7zn5zj1hvhh5yzhccpw0000gn/T/pip-ephem-wheel-cache-sta0y3cz/wheels/34/69/04/e349855a61f14eefa9462752026fe6a1b8af5334ac27b4ce56
# Successfully built torch-spatiotemporal
# Installing collected packages: torch-spatiotemporal
#   Attempting uninstall: torch-spatiotemporal
#     Found existing installation: torch-spatiotemporal 0.1.0
#     Uninstalling torch-spatiotemporal-0.1.0:
#       Successfully uninstalled torch-spatiotemporal-0.1.0
# Successfully installed torch-spatiotemporal-0.1.0

# %%
# !python3 imputation/run_imputation.py --stride 100 --workers 12 --epochs 1 --quantile=0.5
# Out:
# Global seed set to 978720655
# 2022-05-08 23:13:30,093 [INFO]: SEED: 978720655
# 2022-05-08 23:13:32,066 [INFO]: Generating mask with base p=0.0
# 2022-05-08 23:13:32,192 [INFO]: ----------------------------------------------------------------------------------------------------
# Hyperparameters:
# quantile            : 0.5
# seed                : 978720655
# precision           : 32
# model_name          : grin
# dataset_name        : la_point
# config              : grin.yaml
# p_fault             : 0.0
# p_noise             : 0.0
# in_sample           : False
# val_len             : 0.1
# test_len            : 0.2
# lr                  : 0.001
# l2_reg              : 0.0
# epochs              : 1
# batches_per_epoch   : 160
# patience            : 50
# grad_clip_val       : 5.0
# use_lr_schedule     : True
# save_preds          : False
# neptune_logger      : False
# project_name        : sandbox
# tags                : ()
# hidden_size         : 64
# ff_size             : 64
# embedding_size      : 8
# n_layers            : 1
# n_nodes             : None
# kernel_size         : 2
# decoder_order       : 1
# layer_norm          : False
# dropout             : 0
# ff_dropout          : 0
# merge_mode          : mlp
# window              : 24
# stride              : 100
# window_lag          : 1
# horizon_lag         : 1
# batch_size          : 32
# mask_scaling        : True
# workers             : 12
# scale_target        : True
# whiten_prob         : 0.05
# prediction_loss_weight: 1.0
# impute_only_missing : True
# warm_up_steps       : (0, 0)
# hpc_exp_number      : None
#
# 2022-05-08 23:13:32,211 [INFO]: Inferred input data-format: [steps, nodes, channels]
# 2022-05-08 23:13:32,211 [INFO]: Inferred input data-format: [steps, nodes, channels]
# 2022-05-08 23:13:32,212 [INFO]: Inferred input data-format: [steps, nodes, channels]
# 2022-05-08 23:13:32,254 [INFO]: Scaler for data: StandardScaler(bias=(1, 1, 1), scale=(1, 1, 1))
# /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pytorch_lightning/utilities/parsing.py:261: UserWarning: Attribute 'loss_fn' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss_fn'])`.
#   rank_zero_warn(
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /Users/usi/gitspace/gdl-2022/log/imputation/la_point/grin/2022-05-08_23-13-32_978720655/2022-05-08_23-13-32_978720655_grin_la_point
# /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:611: UserWarning: Checkpoint directory /Users/usi/gitspace/gdl-2022/log/imputation/la_point/grin/2022-05-08_23-13-32_978720655 exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
#
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | loss_fn       | MaskedQuantileLoss | 0
# 1 | train_metrics | MetricCollection   | 0
# 2 | val_metrics   | MetricCollection   | 0
# 3 | test_metrics  | MetricCollection   | 0
# 4 | model         | GRINModel          | 214 K
# -----------------------------------------------------
# 214 K     Trainable params
# 0         Non-trainable params
# 214 K     Total params
# 0.857     Total estimated model params size (MB)
# /Users/usi/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py:1927: PossibleUserWarning: The number of training batches (7) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0:  88%|██████████████  | 7/8 [03:25<00:29, 29.29s/it, loss=1.53, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:23<?, ?it/s]
# Epoch 0: 100%|█| 8/8 [03:58<00:00, 29.82s/it, loss=1.53, v_num=0, val_mae=13.00,
# Epoch 0: 100%|█| 8/8 [03:58<00:00, 29.82s/it, loss=1.53, v_num=0, val_mae=13.00,
# Testing DataLoader 0: 100%|███████████████████████| 3/3 [00:46<00:00, 15.46s/it]
# ────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────
#         test_loss           2.9898087978363037
#         test_mae            12.383840560913086
#         test_mape           0.2914915978908539
#      test_mqe-0_025          2.96061110496521
#       test_mqe-0_5           6.191920280456543
#      test_mqe-0_975          9.423229217529297
#         test_mre            0.21290121972560883
#         test_mse             191.6150360107422
# ────────────────────────────────────────────────────────────────────────────────
# Predicting DataLoader 0: 100%|████████████████████| 3/3 [00:48<00:00, -0.08it/s]
# Predicting DataLoader 0: 100%|████████████████████| 1/1 [00:34<00:00, -0.17it/s]
# model saved at: saved_model/0.5/model.pt
# 2022-05-08 23:20:16,063 [INFO]: {'test_mae': 12.383841, 'test_mre': 0.21290119695398296, 'test_mape': 0.29149163, 'val_mae': 12.965536, 'val_mre': 0.21892253365357447, 'val_mape': 0.30401185}
